# %% [markdown]
# # QAOA for Max-Cut: Experiments and Analysis
#
# This notebook walks through the implementation and benchmarking of the Quantum Approximate Optimization Algorithm (QAOA) for the Max-Cut problem.
#
# **What we'll cover:**
# 1. Understanding the Max-Cut problem and how QAOA encodes it
# 2. Running QAOA on small example graphs
# 3. Benchmarking: how does solution quality scale with circuit depth (p)?
# 4. Comparing QAOA performance across different graph structures
#
# The goal is to understand the practical tradeoffs of QAOA — where it works well, where it struggles, and how the choice of `p` affects the results.

# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from pathlib import Path

from src.qaoa_solver import QAOAMaxCutSolver
from src.maxcut_utils import (
    generate_random_graph, generate_regular_graph, generate_cycle_graph,
    brute_force_maxcut, compute_cut_value
)

# so plots show up inline
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

RESULTS_DIR = Path('../results')
RESULTS_DIR.mkdir(exist_ok=True)

print('Setup complete!')

# %% [markdown]
# ## 1. The Max-Cut Problem
#
# Max-Cut is a classic combinatorial optimization problem: given a graph $G = (V, E)$, partition the vertices into two sets $S$ and $\bar{S}$ such that the number of edges between the two sets is maximized.
#
# This is NP-hard in general, which is what makes it interesting for quantum computing — QAOA offers a systematic way to get approximate solutions.
#
# Let's start with a small example to build intuition.

# %%
# create a small graph to visualize
G_example = generate_random_graph(n_nodes=5, edge_prob=0.6, seed=42)

# find the exact solution
exact_cut, exact_partition = brute_force_maxcut(G_example)
print(f"Graph has {G_example.number_of_nodes()} nodes and {G_example.number_of_edges()} edges")
print(f"Optimal cut value: {exact_cut}")
print(f"Optimal partition: {exact_partition}")

# visualize with the partition colored
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

pos = nx.spring_layout(G_example, seed=42)

# plain graph
nx.draw(G_example, pos, ax=axes[0], with_labels=True, node_color='lightblue',
        node_size=500, font_size=14, edge_color='gray', width=2)
axes[0].set_title('Original Graph')

# graph with optimal partition
colors = ['#FF6B6B' if b == 0 else '#4ECDC4' for b in exact_partition]
cut_edges = []
non_cut_edges = []
nodes = list(G_example.nodes())
for u, v in G_example.edges():
    i, j = nodes.index(u), nodes.index(v)
    if exact_partition[i] != exact_partition[j]:
        cut_edges.append((u, v))
    else:
        non_cut_edges.append((u, v))

nx.draw_networkx_nodes(G_example, pos, ax=axes[1], node_color=colors, node_size=500)
nx.draw_networkx_labels(G_example, pos, ax=axes[1], font_size=14)
nx.draw_networkx_edges(G_example, pos, edgelist=non_cut_edges, ax=axes[1],
                       edge_color='lightgray', width=1.5)
nx.draw_networkx_edges(G_example, pos, edgelist=cut_edges, ax=axes[1],
                       edge_color='red', width=2.5, style='dashed')
axes[1].set_title(f'Optimal Cut (value = {exact_cut})')

plt.tight_layout()
plt.savefig(RESULTS_DIR / 'example_graph.png', dpi=150, bbox_inches='tight')
plt.show()
print("Red dashed edges are the ones being cut.")

# %% [markdown]
# ## 2. Running QAOA on a Small Graph
#
# Now let's see how QAOA does on this same graph. We'll try different depths (p=1 through p=5) and see how the solution quality improves.
#
# The key thing to watch is the **approximation ratio** — this is the ratio of QAOA's cut value to the exact optimal cut. A ratio of 1.0 means QAOA found the optimal solution.

# %%
# run QAOA at different depths on our example graph
p_values = [1, 2, 3, 4, 5]
results_by_p = {}

for p in p_values:
    solver = QAOAMaxCutSolver(G_example, p=p, seed=42)
    result = solver.solve(maxiter=300)
    results_by_p[p] = result
    print(f"p={p}: cut={result['best_cut_value']}/{result['exact_cut_value']}, "
          f"approx_ratio={result['approx_ratio']:.4f}, "
          f"partition={result['best_partition']}")

# %%
# plot convergence curves for each depth
fig, ax = plt.subplots(figsize=(10, 6))

colors = plt.cm.viridis(np.linspace(0.1, 0.9, len(p_values)))

for idx, p in enumerate(p_values):
    history = results_by_p[p]['cost_history']
    # convert from negative costs back to positive cut values
    cut_values = [-c for c in history]
    ax.plot(range(len(cut_values)), cut_values, label=f'p={p}',
            color=colors[idx], linewidth=1.5, alpha=0.8)

ax.axhline(y=exact_cut, color='red', linestyle='--', linewidth=1.5,
           label=f'Exact optimum ({exact_cut})', alpha=0.7)
ax.set_xlabel('Optimization Iteration')
ax.set_ylabel('Expected Cut Value')
ax.set_title('QAOA Convergence at Different Depths (5-node graph)')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(RESULTS_DIR / 'convergence_by_depth.png', dpi=150)
plt.show()

# %% [markdown]
# ## 3. Scaling Behavior: How does QAOA perform as graphs get bigger?
#
# This is the important question. We know QAOA works well on tiny graphs, but how does it scale?
#
# We'll sweep across graph sizes from 3 to 10 nodes, with QAOA depths from 1 to 5. For each setting, we run multiple trials with different random graphs to get error bars.
#
# **Note:** This takes a few minutes to run since we're doing a lot of optimizations.

# %%
# sweep over graph sizes and QAOA depths
node_range = range(3, 11)
p_range = range(1, 6)
n_trials = 5

benchmark_results = {}

for n in node_range:
    for p in p_range:
        ratios = []
        for trial in range(n_trials):
            seed = trial * 100 + n * 10 + p
            G = generate_random_graph(n, edge_prob=0.5, seed=seed)
            
            # skip if graph is disconnected
            if not nx.is_connected(G):
                continue
            
            solver = QAOAMaxCutSolver(G, p=p, seed=seed)
            result = solver.solve(maxiter=200)
            ratios.append(result['approx_ratio'])
        
        if ratios:
            benchmark_results[(n, p)] = {
                'mean': np.mean(ratios),
                'std': np.std(ratios),
            }
    print(f"Done with n={n}")

print("\nBenchmark complete!")

# %%
# plot 1: approximation ratio vs QAOA depth, one line per graph size
fig, ax = plt.subplots(figsize=(10, 6))

node_counts = sorted(set(n for n, p in benchmark_results.keys()))
p_vals = sorted(set(p for n, p in benchmark_results.keys()))
colors = plt.cm.viridis(np.linspace(0, 0.85, len(node_counts)))

for idx, n in enumerate(node_counts):
    means = [benchmark_results[(n, p)]['mean'] for p in p_vals if (n, p) in benchmark_results]
    stds = [benchmark_results[(n, p)]['std'] for p in p_vals if (n, p) in benchmark_results]
    valid_p = [p for p in p_vals if (n, p) in benchmark_results]
    
    ax.errorbar(valid_p, means, yerr=stds, marker='o', label=f'n={n}',
               color=colors[idx], capsize=3, linewidth=1.5)

ax.set_xlabel('QAOA Depth (p)')
ax.set_ylabel('Approximation Ratio')
ax.set_title('QAOA Approximation Ratio vs Circuit Depth')
ax.legend(title='Graph Size', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_ylim(0.5, 1.05)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(RESULTS_DIR / 'approx_ratio_vs_p.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# plot 2: approximation ratio vs graph size, one line per depth
fig, ax = plt.subplots(figsize=(10, 6))

colors2 = plt.cm.plasma(np.linspace(0.1, 0.9, len(p_vals)))

for idx, p in enumerate(p_vals):
    means = [benchmark_results[(n, p)]['mean'] for n in node_counts if (n, p) in benchmark_results]
    stds = [benchmark_results[(n, p)]['std'] for n in node_counts if (n, p) in benchmark_results]
    valid_n = [n for n in node_counts if (n, p) in benchmark_results]
    
    ax.errorbar(valid_n, means, yerr=stds, marker='s', label=f'p={p}',
               color=colors2[idx], capsize=3, linewidth=1.5)

ax.set_xlabel('Number of Qubits (Graph Nodes)')
ax.set_ylabel('Approximation Ratio')
ax.set_title('QAOA Performance vs Problem Size')
ax.legend(title='QAOA Depth')
ax.set_ylim(0.5, 1.05)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(RESULTS_DIR / 'approx_ratio_vs_nodes.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Graph Structure Comparison
#
# Different graph structures have different Max-Cut properties. Regular graphs and cycle graphs have more symmetry, which could help or hurt QAOA.
#
# Let's compare three types:
# - **Erdos-Renyi**: random edges, the "typical" case
# - **Regular (degree 3)**: every node has exactly 3 neighbors
# - **Cycle**: each node connected to its two neighbors in a ring
#
# The cycle graph is interesting because its Max-Cut is known analytically — for an even cycle of n nodes, the maximum cut is n (alternate colors). For odd n, it's n-1.

# %%
n_compare = 6  # nodes for comparison
n_trials_gt = 3

graph_results = {}

# Erdos-Renyi
graph_results['Erdos-Renyi'] = {}
for p in range(1, 6):
    ratios = []
    for t in range(n_trials_gt):
        G = generate_random_graph(n_compare, 0.5, seed=t*50+p)
        solver = QAOAMaxCutSolver(G, p=p, seed=t*50+p)
        res = solver.solve(maxiter=200)
        ratios.append(res['approx_ratio'])
    graph_results['Erdos-Renyi'][p] = {'mean': np.mean(ratios), 'std': np.std(ratios)}

# Regular
graph_results['Regular (d=3)'] = {}
for p in range(1, 6):
    ratios = []
    for t in range(n_trials_gt):
        G = generate_regular_graph(n_compare, 3, seed=t*50+p)
        solver = QAOAMaxCutSolver(G, p=p, seed=t*50+p)
        res = solver.solve(maxiter=200)
        ratios.append(res['approx_ratio'])
    graph_results['Regular (d=3)'][p] = {'mean': np.mean(ratios), 'std': np.std(ratios)}

# Cycle
graph_results['Cycle'] = {}
for p in range(1, 6):
    ratios = []
    for t in range(n_trials_gt):
        G = generate_cycle_graph(n_compare)
        solver = QAOAMaxCutSolver(G, p=p, seed=t*50+p)
        res = solver.solve(maxiter=200)
        ratios.append(res['approx_ratio'])
    graph_results['Cycle'][p] = {'mean': np.mean(ratios), 'std': np.std(ratios)}

print("Graph type comparison complete!")

# %%
fig, ax = plt.subplots(figsize=(10, 6))

style = {
    'Erdos-Renyi': {'color': '#FF6B6B', 'marker': 'o'},
    'Regular (d=3)': {'color': '#4ECDC4', 'marker': 's'},
    'Cycle': {'color': '#45B7D1', 'marker': '^'},
}

for gtype, p_data in graph_results.items():
    p_list = sorted(p_data.keys())
    means = [p_data[p]['mean'] for p in p_list]
    stds = [p_data[p]['std'] for p in p_list]
    
    ax.errorbar(p_list, means, yerr=stds,
               marker=style[gtype]['marker'],
               color=style[gtype]['color'],
               label=gtype, capsize=3, linewidth=1.5)

ax.set_xlabel('QAOA Depth (p)')
ax.set_ylabel('Approximation Ratio')
ax.set_title(f'QAOA Performance by Graph Type (n={n_compare})')
ax.legend()
ax.set_ylim(0.6, 1.05)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(RESULTS_DIR / 'graph_type_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ## 5. Measurement Distribution Analysis
#
# One thing that's not obvious from just the approximation ratio is *how concentrated* the QAOA output distribution is around good solutions. Let's look at the measurement histogram for a single run and compare low-p vs high-p.

# %%
G_hist = generate_random_graph(5, 0.6, seed=42)
exact_val, _ = brute_force_maxcut(G_hist)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for idx, p in enumerate([1, 5]):
    solver = QAOAMaxCutSolver(G_hist, p=p, shots=8192, seed=42)
    result = solver.solve(maxiter=300)
    counts = result['measurement_counts']
    
    # sort by cut value
    bitstrings = sorted(counts.keys(), key=lambda b: compute_cut_value(G_hist, [int(x) for x in b[::-1]]))
    cut_vals = [compute_cut_value(G_hist, [int(x) for x in b[::-1]]) for b in bitstrings]
    probs = [counts[b] / 8192 for b in bitstrings]
    
    # color by quality
    colors_bar = ['#4CAF50' if cv == exact_val else '#FFC107' if cv >= exact_val - 1 else '#F44336'
                  for cv in cut_vals]
    
    axes[idx].bar(range(len(bitstrings)), probs, color=colors_bar)
    axes[idx].set_xlabel('Bitstring (sorted by cut value)')
    axes[idx].set_ylabel('Probability')
    axes[idx].set_title(f'QAOA Output Distribution (p={p})')
    axes[idx].set_xticks(range(len(bitstrings)))
    axes[idx].set_xticklabels([f'{b}\n(cut={cv})' for b, cv in zip(bitstrings, cut_vals)],
                              rotation=90, fontsize=6)

plt.tight_layout()
plt.savefig(RESULTS_DIR / 'measurement_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print("Green = optimal, Yellow = near-optimal, Red = far from optimal")

# %% [markdown]
# ## Summary
#
# **Key takeaways from these experiments:**
#
# 1. **QAOA depth matters** — going from p=1 to p=3 gives the biggest improvement in solution quality. Beyond p=3, we see diminishing returns for small graphs.
#
# 2. **Scaling is the challenge** — as graph size increases, QAOA needs higher p to maintain the same approximation ratio. This is consistent with theoretical results.
#
# 3. **Graph structure affects performance** — structured graphs like cycles tend to be easier for QAOA than random Erdos-Renyi graphs. This makes sense because the symmetry helps the variational optimization.
#
# 4. **QAOA concentrates probability on good solutions** — at higher p, the output distribution clearly shifts toward optimal and near-optimal bitstrings.
#
# For a real application, you'd want to go beyond simulation to actual quantum hardware, where noise becomes a major factor. That's a project for another day.
